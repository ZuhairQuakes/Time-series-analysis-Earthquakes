# %%
import pandas as pd
import numpy as np
from numpy import diff

from scipy.stats import ttest_ind

import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import ternary # ternary plot has a bug
import plotly.express as px
import h5py
import matplotlib as mpl

# import geopandas as gpd
import math

from matplotlib.patches import Circle, Wedge, Polygon

import os
import matplotlib.patheffects as path_effects


from netCDF4 import Dataset as NetCDFFile 

# for beachball - there are some error with using obspy
from pyrocko.plot import beachball
from pyrocko import moment_tensor as ptm

import cartopy.crs as ccrs
import cartopy.mpl.geoaxes

from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import matplotlib.ticker as mticker
from pathlib import Path
# %matplotlib inline

import harmonica as hm

from obspy.core import UTCDateTime

from datetime import datetime, timezone

import seaborn as sns
sns.set()
sns.set_style(style='white') 
sns.set_style("ticks", {"xtick.major.size": 0.5, "ytick.major.size": 0.5})


#set the font globally
plt.rcParams.update({'font.family':'Helvetica'})

# %%
# data = pd.read_csv('sum_with_2005_eqs.csv', header = 'infer')
data = pd.read_csv("/Users/mohd0001/PhD_Monash/Paper2/time-series/data/ryu_kur_combi_no_Izu.csv", header = 'infer')
# data.dtypes

# data = data[(data['MW'] >= 5.1)]

data.sort_values(by = 'MW', ascending = False, inplace = True)

data['DATE'] = pd.to_datetime(data['DATE']) # change dtype to datetime format
data['DATE'] = data['DATE'].dt.strftime('%Y-%m-%d') # change dtype to object

# data['DATE'] and data['TIME'] should be object (str) to perform + operator

data_dummy = np.array(data['DATE'] + ' ' + data['TIME'])

data_ev_time = []

for val in data_dummy:
    data_ev_time.append(UTCDateTime(val))

    
ref_date = data_ev_time[0]

data_ev_time = np.array(data_ev_time)

date = []

for val in data_ev_time:
    date.append(val - ref_date)
    
date = np.array(date) # this is in seconds

data['YEARS'] = date/31536000

data = data.sort_values(by ='YEARS', ascending=True) # this is an important step
# data = data[(data['DATE'] > '01-01-2003') & (data['DATE'] < '26-11-2004')]

# %%
## olive band

t1 = -35
t2 = -31


data_DW = data[(data['DEPTH'] > 100) & (data['DEPTH'] < 500) &
               (data['MW'] >= 6) &
              (data['LAT'] > 45) & (data['LON'] > 143)] # just Kuril-Kamchatka

data_DW = data_DW[(data_DW['YEARS'] > t1) & (data_DW['YEARS'] < t2)]

# print('Olive band')
print('Long slab')
print(data_DW[['LAT','LON','DEPTH', 'YEARS', 'MW', 'DATE']])

data_mthrust = data[(data['DEPTH'] < 40) &
                    (data['MW'] >= 7) &
                   (data['LAT'] > 34) & (data['LAT'] < 58)] # Japan-Kuril-Kamchatka

data_mthrust = data_mthrust[(data_mthrust['YEARS'] > t1) & (data_mthrust['YEARS'] < t2)]

print('Megathrust')
print(data_mthrust[['LAT','LON','DEPTH', 'YEARS', 'MW', 'DATE']])
# Out:
# Long slab
#          LAT      LON  DEPTH      YEARS   MW        DATE
# 1386  47.309  145.772  416.4 -34.689743  6.1  1976-07-10
# 1294  51.629  155.308  240.0 -33.488669  6.3  1977-09-21
# 1242  48.262  148.587  407.7 -32.741849  6.5  1978-06-21
# Megathrust
#          LAT      LON  DEPTH      YEARS   MW        DATE
# 1160  44.310  148.950   28.2 -32.989641  7.0  1978-03-23
# 1125  45.085  148.257   25.0 -32.989328  7.6  1978-03-23
# 1128  44.243  148.916   12.3 -32.984700  7.5  1978-03-24
# 1150  43.602  146.697   33.9 -31.065744  7.1  1980-02-23

# %%
## green band -27.8

t1 = -29.8
t2 = -25.8


data_DW = data[(data['DEPTH'] > 100) & (data['DEPTH'] < 500) &
               (data['MW'] >= 6) &
              (data['LAT'] > 45) & (data['LON'] > 143)] # just Kuril-Kamchatka

data_DW = data_DW[(data_DW['YEARS'] > t1) & (data_DW['YEARS'] < t2)]

# print('Olive band')
print('Long slab')
print(data_DW[['LAT','LON','DEPTH', 'YEARS', 'MW', 'DATE']])

data_mthrust = data[(data['DEPTH'] < 40) &
                    (data['MW'] >= 7) &
                   (data['LAT'] > 34) & (data['LAT'] < 58)] # Japan-Kuril-Kamchatka

data_mthrust = data_mthrust[(data_mthrust['YEARS'] > t1) & (data_mthrust['YEARS'] < t2)]

print('Megathrust')
print(data_mthrust[['LAT','LON','DEPTH', 'YEARS', 'MW', 'DATE']])
# Out:
# Long slab
#          LAT      LON  DEPTH      YEARS   MW        DATE
# 1360  53.842  158.398  181.4 -27.647334  6.2  1983-07-24
# 1237  47.419  146.714  419.9 -26.896815  6.5  1984-04-23
# Megathrust
#          LAT      LON  DEPTH      YEARS   MW        DATE
# 1145  44.717  151.103   19.3 -28.715504  7.1  1982-06-30
# 1152  36.315  141.784   22.6 -28.651070  7.0  1982-07-23
# 1119  40.476  139.115   17.1 -27.811275  7.7  1983-05-26
# 1148  44.192  148.141   37.7 -26.980370  7.1  1984-03-24
